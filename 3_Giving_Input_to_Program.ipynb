# %%
myInputVar = input('Enter a number:')
print(myInputVar)
# Out:
# 3

# %%
# a program which takes two numbers as inputs from the user and adds them
num1 = int(input("Enter First number: "))   # input for first number
num2 = int(input("Enter Second number: "))  # input for second number
sum = num1 + num2   # adding num1 and num2 and storing them in sum
print(sum)  # print sum to the screen
# Out:
# 4
