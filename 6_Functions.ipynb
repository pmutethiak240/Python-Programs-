# %%
sum1 = num1 + num2
sum2 = num3 + num4
sum3 = num5 + num6

# %%
# Anatomy of a Python function

def functionName (parameters):
    statements
    return something

# %%
def greet_user():
    print("Hello! Welcome back.")

greet_user()
# Out:
# Hello! Welcome back.

# %%
def personalize_greet(name):    # name is a parameter (placeholder)
    print(f"Hello, {name}! Welcome back.")

# Now we call it and pass in the actual value (the argument)
personalize_greet("Alice")  
personalize_greet("Bob")
# Out:
# Hello, Alice! Welcome back.
# Hello, Bob! Welcome back.

# %%
def add_numbers(a, b):
    return a + b

# We can save it to a variable because it returns a value
total = add_numbers(5, 7)
print(total)
# Out:
# 12

# %%
def helloWorld():
    print("Hello World")

# %%
def addNumbers(num1, num2):
    sum = num1 + num2
    return sum

# %%
# Syntax for calling a function

functionName(parameters)

# %%
def helloWorld():   # Define the helloWorld function
    print("Hello World")

helloWorld()    # Call the helloWorld function
# Out:
# Hello World

# %%
def addNumbers(num1, num2):
    sum = num1 + num2
    print(sum)
    return 

addNumbers(2,3)
addNumbers(4,5)
# Out:
# 5
# 9

# %%
def subtract(a,b):
    diff = a-b
    print(diff)

subtract(4,3)
# Out:
# 1

# %%
def squareNum(num1):
    mul = num1 * num1
    print(mul)

squareNum(12)
# Out:
# 144

# %%
name = "Bob"

# Case A: Using quotes
print("name")   # Output: name

# Case B: No quotes
print(name)     # Output: Bob
# Out:
# name
# Bob
