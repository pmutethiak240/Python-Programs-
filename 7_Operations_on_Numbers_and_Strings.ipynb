# %%
# To import a module

import moduleName
import math

# %%
import math
math.pow(4,3)
# Out:
# 64.0

# %%
import math
a = math.floor(4.3)
b = math.floor(10.9)
print (a)
print (b)
# Out:
# 4
# 10

# %%
import math
a = math.ceil(4.3)
b = math.ceil(10.9)
print (a)
print (b)
# Out:
# 5
# 11

# %%
import math
a = math.floor(5.3)
b = math.ceil(1.6)
print (a)
print (b)
# Out:
# 5
# 2

# %%
a = abs(10)
b = abs(-10)
print (a)
print (b)
# Out:
# 10
# 10

# %%
import math
a = math.log(10)
b = math.log(10,2)
print (a)
print (b)
# Out:
# 2.302585092994046
# 3.3219280948873626

# %%
import math
a = math.sqrt(9)
b = math.sqrt(16)
print (a)
print (b)
# Out:
# 3.0
# 4.0

# %%
import math
a = math.sqrt(25)
b = math.sqrt(16)
print (a)
print (b)
# Out:
# 5.0
# 4.0

# %%
num1 = 'this is a string.'

num2 = "this is also a string."

num3 = '''this looks somewhat different
    It is really different you can see
multiple lines in this string
Isn't is awesome'''

# %%
str.functionName()

# %%
str = "here I Am."
str.capitalize()
# Out:
# 'Here i am.'

# %%
str = "here I Am."
str.count("e")
# Out:
# 2

# %%
str = "here I Am."
str.count('Am')
# Out:
# 1

# %%
str = "where aRe yoU GoiNg."
str.count("e")
# Out:
# 3

# %%
str.capitalize()
# Out:
# 'Where are you going.'

# %%
str = "here I Am."
a = str.find("h")
print(a)
# Out:
# 0

# %%
str = "Who are you?"
a = str.find("o")
print(a)
# Out:
# 2

# %%
str = " "
iter = ("I","am","awesome.")
a = str.join(iter)
print(a)
# Out:
# I am awesome.

# %%
str = "-"
iter = ("I","am","awesome.")
a = str.join(iter)
print(a)
# Out:
# I-am-awesome.
