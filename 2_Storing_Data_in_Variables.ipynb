# %%
myVar = 60

# %%
myVar1 = "Hello"
#How strings are stored in Python

# %%
myVar = 2   # An integer
myVar = 25.54   # A floating point

# %%
score = 10
# First, the box holds a score of 10

score = 15
# Now, we throw out the 10 and put 15 in the same box

# %%
# Python sees this as math
age1 = 23

# Python sees this as text, just like the word Hello
age2 = "23"

age1 * 2
age2 * 2
# Out:
# '2323'
